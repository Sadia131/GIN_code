# %%
# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-1.9.0+cu111.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-1.9.0+cu111.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# %%
import argparse
import os.path as osp

import torch
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.datasets import UPFD
from torch_geometric.data import DataLoader
from torch_geometric.transforms import ToUndirected
from torch_geometric.nn import GCNConv, SAGEConv, GATConv, global_max_pool, global_mean_pool
from torch_geometric.nn import GINConv, global_add_pool,GINEConv
from torch.nn import Sequential, Linear, BatchNorm1d, ReLU

# %%
path = osp.join(osp.dirname(osp.realpath("/content/tutorial1")), '..', 'data', 'UPFD')
train_dataset = UPFD(path, 'gossipcop', 'bert', 'train', ToUndirected())
val_dataset = UPFD(path, 'gossipcop', 'bert', 'val', ToUndirected())
test_dataset = UPFD(path, 'gossipcop', 'bert', 'test', ToUndirected())

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch_geometric/deprecation.py:13: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
print(val_dataset)
# Out:
# UPFD(546, name=gossipcop, feature=bert)

# %%
class Net(torch.nn.Module):
    def __init__(self, in_channels, dim, out_channels):
        super(Net, self).__init__()

        self.conv1 = GINConv(
            Sequential(Linear(in_channels, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.conv2 = GINConv(
            Sequential(Linear(dim, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.conv3 = GINConv(
            Sequential(Linear(dim, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.conv4 = GINConv(
            Sequential(Linear(dim, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.conv5 = GINConv(
            Sequential(Linear(dim, dim), BatchNorm1d(dim), ReLU(),
                       Linear(dim, dim), ReLU()))

        self.lin1 = Linear(dim, dim)
        self.lin2 = Linear(dim, out_channels)

    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = self.conv2(x, edge_index)
        x = self.conv3(x, edge_index)
        x = self.conv4(x, edge_index)
        x = self.conv5(x, edge_index)
        x = global_add_pool(x, batch)
        x = self.lin1(x).relu()
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net(train_dataset.num_features, 180, train_dataset.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


def train():
    model.train()

    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x, data.edge_index, data.batch)
        loss = F.nll_loss(output, data.y)
        loss.backward()
        optimizer.step()
        total_loss += float(loss) * data.num_graphs
    return total_loss / len(train_loader.dataset)


@torch.no_grad()
def test(loader):
    model.eval()

    total_correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data.x, data.edge_index, data.batch)
        total_correct += int((out.argmax(-1) == data.y).sum())
    return total_correct / len(loader.dataset)

# %%
loss = []
train_acc = []
test_acc = []

for epoch in range(1, 101):
    loss.append(train())
    train_acc.append(test(train_loader))
    test_acc.append(test(test_loader))
    print(f'Epoch: {epoch:03d}, Loss: {loss[-1]:.4f}, Train Acc: {train_acc[-1]:.4f} '
          f'Test Acc: {test_acc[-1]:.4f}')
# Out:
# Epoch: 001, Loss: 0.0597, Train Acc: 0.9652 Test Acc: 0.9174
# Epoch: 002, Loss: 0.0454, Train Acc: 0.9725 Test Acc: 0.9200
# Epoch: 003, Loss: 0.0493, Train Acc: 0.8571 Test Acc: 0.8236
# Epoch: 004, Loss: 0.0490, Train Acc: 0.8269 Test Acc: 0.7888
# Epoch: 005, Loss: 0.0233, Train Acc: 0.7564 Test Acc: 0.7269
# Epoch: 006, Loss: 0.0284, Train Acc: 0.9560 Test Acc: 0.8955
# Epoch: 007, Loss: 0.0216, Train Acc: 0.9936 Test Acc: 0.9420
# Epoch: 008, Loss: 0.0626, Train Acc: 0.9615 Test Acc: 0.9096
# Epoch: 009, Loss: 0.0404, Train Acc: 0.9908 Test Acc: 0.9422
# Epoch: 010, Loss: 0.0247, Train Acc: 0.9762 Test Acc: 0.9187
# Epoch: 011, Loss: 0.0274, Train Acc: 0.9432 Test Acc: 0.8680
# Epoch: 012, Loss: 0.0729, Train Acc: 0.8956 Test Acc: 0.8508
# Epoch: 013, Loss: 0.0315, Train Acc: 0.9918 Test Acc: 0.9341
# Epoch: 014, Loss: 0.0355, Train Acc: 0.9313 Test Acc: 0.8774
# Epoch: 015, Loss: 0.0536, Train Acc: 0.9579 Test Acc: 0.9104
# Epoch: 016, Loss: 0.0964, Train Acc: 0.9597 Test Acc: 0.9064
# Epoch: 017, Loss: 0.0552, Train Acc: 0.7729 Test Acc: 0.7522
# Epoch: 018, Loss: 0.0274, Train Acc: 0.6996 Test Acc: 0.6887
# Epoch: 019, Loss: 0.0309, Train Acc: 0.9890 Test Acc: 0.9307
# Epoch: 020, Loss: 0.0309, Train Acc: 0.9560 Test Acc: 0.9004
# Epoch: 021, Loss: 0.0353, Train Acc: 0.9414 Test Acc: 0.9004
# Epoch: 022, Loss: 0.0667, Train Acc: 0.9899 Test Acc: 0.9334
# Epoch: 062, Loss: 0.0078, Train Acc: 0.9973 Test Acc: 0.9192
# Epoch: 063, Loss: 0.0060, Train Acc: 0.9725 Test Acc: 0.8941
# Epoch: 064, Loss: 0.0332, Train Acc: 1.0000 Test Acc: 0.9320
# Epoch: 065, Loss: 0.0394, Train Acc: 0.9945 Test Acc: 0.9242
# Epoch: 066, Loss: 0.0454, Train Acc: 0.9716 Test Acc: 0.9022
# Epoch: 067, Loss: 0.0193, Train Acc: 0.9817 Test Acc: 0.9224
# Epoch: 068, Loss: 0.0303, Train Acc: 0.6502 Test Acc: 0.6477
# Epoch: 069, Loss: 0.0219, Train Acc: 0.9066 Test Acc: 0.8489
# Epoch: 070, Loss: 0.0077, Train Acc: 0.9973 Test Acc: 0.9203
# Epoch: 071, Loss: 0.0098, Train Acc: 0.9368 Test Acc: 0.8751
# Epoch: 072, Loss: 0.0054, Train Acc: 0.9918 Test Acc: 0.9203
# Epoch: 073, Loss: 0.0187, Train Acc: 0.8114 Test Acc: 0.7721
# Epoch: 074, Loss: 0.0274, Train Acc: 0.7573 Test Acc: 0.7258
# Epoch: 075, Loss: 0.0253, Train Acc: 0.9780 Test Acc: 0.8973
# Epoch: 076, Loss: 0.0216, Train Acc: 0.9231 Test Acc: 0.8638
# Epoch: 077, Loss: 0.0147, Train Acc: 0.6804 Test Acc: 0.6756
# Epoch: 078, Loss: 0.0402, Train Acc: 0.9698 Test Acc: 0.9122
# Epoch: 079, Loss: 0.0308, Train Acc: 0.9652 Test Acc: 0.9020
# Epoch: 080, Loss: 0.0541, Train Acc: 0.9341 Test Acc: 0.8680
# Epoch: 081, Loss: 0.0671, Train Acc: 0.9762 Test Acc: 0.9185
# Epoch: 082, Loss: 0.0411, Train Acc: 0.9817 Test Acc: 0.9166
# Epoch: 083, Loss: 0.0305, Train Acc: 0.9817 Test Acc: 0.9190
# Epoch: 084, Loss: 0.0271, Train Acc: 0.9808 Test Acc: 0.9119
# Epoch: 085, Loss: 0.0570, Train Acc: 0.9881 Test Acc: 0.9190
# Epoch: 086, Loss: 0.0261, Train Acc: 0.9625 Test Acc: 0.8988
# Epoch: 087, Loss: 0.0183, Train Acc: 1.0000 Test Acc: 0.9328
# Epoch: 088, Loss: 0.0105, Train Acc: 0.9991 Test Acc: 0.9234
# Epoch: 089, Loss: 0.0443, Train Acc: 0.9634 Test Acc: 0.9028
# Epoch: 090, Loss: 0.0353, Train Acc: 0.9762 Test Acc: 0.9200
# Epoch: 091, Loss: 0.0229, Train Acc: 0.9359 Test Acc: 0.8871
# Epoch: 092, Loss: 0.0222, Train Acc: 0.9808 Test Acc: 0.9059
# Epoch: 093, Loss: 0.0374, Train Acc: 0.9945 Test Acc: 0.9289
# Epoch: 094, Loss: 0.0324, Train Acc: 0.8965 Test Acc: 0.8408
# Epoch: 095, Loss: 0.0332, Train Acc: 0.9835 Test Acc: 0.9117
# Epoch: 096, Loss: 0.0629, Train Acc: 0.9222 Test Acc: 0.8479
# Epoch: 097, Loss: 0.0228, Train Acc: 0.9927 Test Acc: 0.9239
# Epoch: 098, Loss: 0.0295, Train Acc: 0.9908 Test Acc: 0.9216
# Epoch: 099, Loss: 0.0350, Train Acc: 0.9295 Test Acc: 0.8939
# Epoch: 100, Loss: 0.0503, Train Acc: 0.9487 Test Acc: 0.9015

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt

plt.plot(train_acc)
plt.plot(test_acc)
plt.title('model accuracy for Bert')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(loss)
plt.title('model loss for Bert')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc='upper left')
plt.show()
